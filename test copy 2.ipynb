# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
#Loading the data
today = str(date.today())
df_branch_service = pd.read_json("branch_service_transaction_info.json")
df_customer_transaction = pd.read_json("customer_transaction_info.json")

# %%
#Profiling the data
df_branch_service.head(10)
# Out:
#       txn_id    branch_name    service  price
# 0  TXN-24546     MallOfAsia   Manicure    NaN
# 1  TXN-14642       Starmall  HairColor    NaN
# 2  TXN-60295      SmallMall    FootSpa    NaN
# 3  TXN-60295       Starmall    FootSpa    NaN
# 4  TXN-60295        MayMall    FootSpa    NaN
# 5  TXN-60295      FrankMall    FootSpa    NaN
# 6  TXN-40462       Starmall  HairColor    NaN
# 7  TXN-40462       Megamall  HairColor    NaN
# 8  TXN-08102  RobinsonsMall  HairColor    NaN
# 9  TXN-08102      SmallMall  HairColor    NaN

# %%
df_customer_transaction.head(10)
# Out:
#       txn_id  avail_date last_name first_name    birthday
# 0  TXN-24546  2030-09-08     ORTIZ    EDUARDO  1990-07-08
# 1  TXN-14642  2026-05-26    NIENOW        LEA  2000-11-26
# 2  TXN-60295  2006-09-25     LESCH      FLETA  1993-05-22
# 3  TXN-60295  2006-09-25     LESCH      FLETA  1993-05-22
# 4  TXN-60295  2006-09-25     LESCH      FLETA  1993-05-22
# 5  TXN-60295  2006-09-25     LESCH      FLETA  1993-05-22
# 6  TXN-40462  2021-08-21      KUHN        TOD  2002-11-25
# 7  TXN-40462  2021-08-21      KUHN        TOD  2002-11-25
# 8  TXN-08102  2010-04-03   JOHNSON     MILTON  2003-07-10
# 9  TXN-08102  2010-04-03   JOHNSON     MILTON  2003-07-10

# %%
print(df_branch_service.shape)
print(df_customer_transaction.shape)
# Out:
# (130653, 4)
# (130653, 5)

# %%
print(df_branch_service['txn_id'].nunique())
print(df_customer_transaction['txn_id'].nunique())
# Out:
# 62354
# 62354

# %%
#Dropping duplicates
df_branch_service = df_branch_service.drop_duplicates(subset=['txn_id'])
df_customer_transaction = df_customer_transaction.drop_duplicates(subset=['txn_id'])

# %%
#confirming shape
print(df_branch_service.shape)
print(df_customer_transaction.shape)
# Out:
# (62354, 4)
# (62354, 5)

# %%
#checking null values count per column
df_branch_service.isnull().sum()
# Out:
# txn_id             0
# branch_name     8880
# service            0
# price          11082
# dtype: int64

# %%
df_customer_transaction.isnull().sum()
# Out:
# txn_id        0
# avail_date    0
# last_name     0
# first_name    0
# birthday      0
# dtype: int64

# %%
#fill up null values with forward fill for branch_name
df_branch_service['branch_name'].unique()
# Out:
# array(['MallOfAsia', 'Starmall', 'SmallMall', 'RobinsonsMall', '', None,
#        'MayMall', 'FrankMall', 'N/A', 'Megamall'], dtype=object)

# %%
#'' and None are empty values, fill them with forward fill
# first, let '' be null
df_branch_service['branch_name'] = df_branch_service.replace('',np.nan).groupby('txn_id')['branch_name'].transform('first')
# then fill null, use forward and backward to fill
df_branch_service['branch_name'] = df_branch_service['branch_name'].ffill().bfill()

# %%
#confirming branch_name has no null
df_branch_service.isnull().sum()
# Out:
# txn_id             0
# branch_name        0
# service            0
# price          11082
# dtype: int64

# %%
df_branch_service['branch_name'].unique()
# Out:
# array(['MallOfAsia', 'Starmall', 'SmallMall', 'RobinsonsMall', 'MayMall',
#        'FrankMall', 'N/A', 'Megamall'], dtype=object)

# %%
# group mean fill prices
df_branch_service['price'] = df_branch_service['price'].fillna(df_branch_service.groupby(['branch_name','service'])['price'].transform('mean'))

# %%
#confirming price has no null
df_branch_service.isnull().sum()
# Out:
# txn_id         0
# branch_name    0
# service        0
# price          0
# dtype: int64

# %%
df_branch_service.head(10)
# Out:
#        txn_id    branch_name    service       price
# 0   TXN-24546     MallOfAsia   Manicure   42.651993
# 1   TXN-14642       Starmall  HairColor   69.583267
# 2   TXN-60295      SmallMall    FootSpa   80.037329
# 6   TXN-40462       Starmall  HairColor   69.583267
# 8   TXN-08102  RobinsonsMall  HairColor   66.735226
# 12  TXN-64262      SmallMall     Rebond  312.646002
# 15  TXN-41934  RobinsonsMall  HairColor   66.735226
# 19  TXN-39050       Starmall   Manicure   43.364281
# 21  TXN-43150       Starmall    Haircut   51.769018
# 22  TXN-49423  RobinsonsMall     Rebond  302.828204

# %%
df_merged = pd.merge(df_customer_transaction, df_branch_service)

# %%
#profiling of merged dataframe
df_merged.isnull().sum()
# Out:
# txn_id         0
# avail_date     0
# last_name      0
# first_name     0
# birthday       0
# branch_name    0
# service        0
# price          0
# dtype: int64

# %%
df_merged.sample(20)
# Out:
#           txn_id  avail_date            last_name        first_name  \
# 21946  TXN-29260  2027-08-28              wiegand            braden
# 46960  TXN-15296  2021-03-05          Schamberger            Albina
# 24235  TXN-51684  2015-12-30          Heidenreich           Bradley
# 18574  TXN-16459  2015-08-08              spencer            jaylin
# 24315  TXN-57405  2012-01-16               Daniel            Monroe
# 857    TXN-21600  2024-05-20           JAKUBOWSKI             LYRIC
# 60596  TXN-18997  2012-12-24              Kuhlman              Ebba
# 17158  TXN-42402  2017-12-31         christiansen           shannon
# 281    TXN-14505  2014-12-30              KEEBLER            RAFAEL
# 25638  TXN-52627  2026-07-11                Kozey            Lessie
# 59897  TXN-32489  2019-06-14              Padberg            Hailie
# 57688  TXN-46685  2009-10-13                Lynch              Hope
# 51381  TXN-52079  2021-11-03             Gislason             Melba
# 43106  TXN-32102  2021-07-31         Metz,,,,,,,,     Sydni........
# 38051  TXN-50571  2021-09-02        Grady,,,,,,,,  Crawford........
# 14053  TXN-35608  2026-03-11                tromp           aurelie
# 8533   TXN-58642  2024-03-26               DURGAN               MAE
# 8837   TXN-36773  2014-03-24                BAUCH           JERAMIE
# 49485  TXN-46858  2017-06-15               Hirthe           Jazmyne
# 36192  TXN-35923  2025-04-19       Stokes,,,,,,,,      Meta........
#
#          birthday    branch_name    service       price
# 21946  2001-08-08       Starmall  HairColor    0.000000
# 46960  1991-04-02       Megamall    Haircut   66.123457
# 24235  2001-01-16       Starmall  NailColor   30.123790
# 18574  1990-10-02       Megamall    Haircut    0.000000
# 24315  1999-11-25     MallOfAsia    Haircut   66.123457
# 857    1990-04-11      SmallMall    Haircut   51.276746
# 60596  2001-02-19  RobinsonsMall    FootSpa  100.121230
# 17158  2002-08-16      SmallMall   Pedicure    0.000000
# 281    2005-01-12      FrankMall  HairColor   67.045741
# 25638  1995-03-06  RobinsonsMall  NailColor   30.123790
# 59897  2008-06-12      SmallMall  NailColor   30.123790
# 57688  1996-09-07       Megamall   Manicure   55.232400
# 51381  2004-04-13       Starmall  HairColor   88.093930
# 43106  2002-08-05     MallOfAsia   Pedicure   77.987989
# 38051  1991-09-22      SmallMall  HairColor   88.093930
# 14053  1998-05-05       Megamall    FootSpa    0.000000
# 8533   1995-11-16      FrankMall    Haircut   49.687416
# 8837   2010-11-27       Megamall    Haircut   50.644998
# 49485  1997-02-12      FrankMall   Pedicure   77.987989
# 36192  1992-08-12  RobinsonsMall  HairColor   88.093930

# %%
#filter alphabet only in last_name and first_name
df_merged['last_name'] = df_merged['last_name'].str.replace('\W', '', regex=True)
df_merged['first_name'] = df_merged['first_name'].str.replace('\W', '', regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\juanc\AppData\Local\Temp\ipykernel_8060\1982014538.py:2: SyntaxWarning: invalid escape sequence '\W'
#   df_merged['last_name'] = df_merged['last_name'].str.replace('\W', '', regex=True)
# C:\Users\juanc\AppData\Local\Temp\ipykernel_8060\1982014538.py:3: SyntaxWarning: invalid escape sequence '\W'
#   df_merged['first_name'] = df_merged['first_name'].str.replace('\W', '', regex=True)

# %%
#uppercase for last_name and first_name
df_merged['last_name'] = df_merged['last_name'].str.upper()
df_merged['first_name'] = df_merged['first_name'].str.upper()

# %%
#check if no special characters and all uppercase for names
df_merged.sample(20)
# Out:
#           txn_id  avail_date    last_name first_name    birthday  \
# 28271  TXN-22367  2024-03-23      FRIESEN    EARNEST  2001-06-03
# 40593  TXN-45127  2006-06-07          ORN    JUANITA  1996-04-22
# 25033  TXN-15683  2009-03-27    HERMISTON   STEPHANY  1990-08-03
# 30251  TXN-60547  2014-04-13      SCHADEN    CARMELO  2009-09-30
# 13636  TXN-08180  2010-04-13         HAHN      DANNY  2009-08-08
# 8299   TXN-10494  2010-11-15     FRANECKI     KAMRYN  1999-01-18
# 45112  TXN-51633  2012-02-27  BREITENBERG     JARRED  1997-02-04
# 9014   TXN-56073  2028-09-04         RYAN     JEANIE  2007-04-03
# 30649  TXN-10352  2018-06-02       HICKLE      LEXUS  2008-01-01
# 51801  TXN-58437  2027-02-17       HARBER       NEAL  1997-02-13
# 35324  TXN-19607  2018-10-25        WALSH    GERARDO  2005-02-13
# 55357  TXN-04408  2018-05-29        JONES      GARRY  2007-02-10
# 754    TXN-60624  2010-02-07         ROOB   JENNYFER  2010-08-21
# 35313  TXN-32631  2016-04-06        SWIFT    LEONARD  1991-04-03
# 43220  TXN-27542  2022-04-21     DONNELLY       OTIS  1990-02-17
# 9147   TXN-41189  2025-03-25       RAYNOR    MAXIMUS  2002-03-03
# 15447  TXN-05263  2017-02-26      SCHMITT    BRIONNA  2002-08-03
# 2308   TXN-17748  2014-11-16       PARKER     MORIAH  2001-12-28
# 60259  TXN-29798  2024-07-09         YOST      LAVON  2001-11-02
# 44067  TXN-39363  2011-04-20         KOCH      GAVIN  2000-09-04
#
#          branch_name    service       price
# 28271     MallOfAsia  HairColor   88.093930
# 40593       Megamall    Haircut   66.123457
# 25033      SmallMall  NailColor   30.123790
# 30251       Starmall    Haircut   66.123457
# 13636     MallOfAsia    FootSpa    0.000000
# 8299   RobinsonsMall   Manicure   41.900441
# 45112        MayMall   Pedicure   77.987989
# 9014        Starmall   Pedicure   61.537398
# 30649     MallOfAsia    FootSpa  100.121230
# 51801        MayMall  NailColor   30.123790
# 35324      FrankMall   Pedicure   77.987989
# 55357       Megamall  NailColor   30.123790
# 754        SmallMall    Haircut   51.276746
# 35313  RobinsonsMall    Haircut   66.123457
# 43220       Starmall   Manicure   55.232400
# 9147         MayMall     Rebond  321.586572
# 15447      SmallMall   Pedicure    0.000000
# 2308       FrankMall   Manicure   44.879880
# 60259  RobinsonsMall    FootSpa  100.121230
# 44067      FrankMall  NailColor   30.123790

# %%
#profiling date columns
print(df_merged['birthday'].min())
print(df_merged['birthday'].max())

print(df_merged['avail_date'].min())
print(df_merged['avail_date'].max())

print(df_merged['avail_date'].describe)
print(df_merged['birthday'].describe)

print(df_merged[(df_merged['avail_date'] <= df_merged['birthday'])])
# Out:
# 1990-01-01
# 2010-12-30
# 2005-01-01
# 2030-12-30
# <bound method NDFrame.describe of 0        2030-09-08
# 1        2026-05-26
# 2        2006-09-25
# 3        2021-08-21
# 4        2010-04-03
#             ...
# 62349    2022-11-21
# 62350    2020-04-14
# 62351    2030-01-26
# 62352    2021-02-27
# 62353    2025-01-05
# Name: avail_date, Length: 62354, dtype: object>
# <bound method NDFrame.describe of 0        1990-07-08
# 1        2000-11-26
# 2        1993-05-22
# 3        2002-11-25
# 4        2003-07-10
#             ...
# 62349    1997-03-06
# 62350    1996-05-28
# 62351    1996-05-28
# 62352    1995-03-29
# 62353    1993-01-10
# Name: birthday, Length: 62354, dtype: object>
#           txn_id  avail_date  last_name first_name    birthday    branch_name  \
# 9      TXN-49423  2008-08-13      BERGE    RASHEED  2010-02-05  RobinsonsMall
# 17     TXN-35244  2005-11-23     HAMMES     EUNICE  2006-06-13      SmallMall
# 97     TXN-23898  2005-05-28   BOTSFORD     GIANNI  2009-03-30  RobinsonsMall
# 101    TXN-17974  2008-04-12   PARISIAN     DALLAS  2008-07-05      FrankMall
# 120    TXN-27802  2006-08-17      BOGAN       FINN  2009-08-09      SmallMall
# ...          ...         ...        ...        ...         ...            ...
# 62140  TXN-58675  2007-07-09      CRIST   CHADRICK  2008-10-11      SmallMall
# 62152  TXN-05601  2005-02-09      SAUER     MALLIE  2009-07-19       Starmall
# 62214  TXN-45694  2005-01-30     LARSON    ALLISON  2009-11-05       Megamall
# 62270  TXN-14858  2005-05-07     HOEGER      CLETA  2007-12-15  RobinsonsMall
# 62303  TXN-39530  2007-12-28  GREENHOLT      GAVIN  2009-05-01       Megamall
#
#          service       price
# 9         Rebond  302.828204
# 17      Manicure   43.522917
# 97       Haircut   51.196577
# 101    NailColor   23.338226
# 120      FootSpa   80.037329
# ...          ...         ...
# 62140   Manicure   55.232400
# 62152    Haircut   66.123457
# 62214     Rebond  400.231230
# 62270     Rebond  400.231230
# 62303    FootSpa  100.121230
#
# [2084 rows x 8 columns]

# %%
#data type of birthday and avail_date should be datetime instead of object
df_merged['avail_date'] = pd.to_datetime(df_merged['avail_date'], format='%Y-%m-%d')
df_merged['birthday'] = pd.to_datetime(df_merged['birthday'], format='%Y-%m-%d')

#confirming
print(df_merged['avail_date'].describe)
print(df_merged['birthday'].describe)
# Out:
# <bound method NDFrame.describe of 0       2030-09-08
# 1       2026-05-26
# 2       2006-09-25
# 3       2021-08-21
# 4       2010-04-03
#            ...
# 62349   2022-11-21
# 62350   2020-04-14
# 62351   2030-01-26
# 62352   2021-02-27
# 62353   2025-01-05
# Name: avail_date, Length: 62354, dtype: datetime64[ns]>
# <bound method NDFrame.describe of 0       1990-07-08
# 1       2000-11-26
# 2       1993-05-22
# 3       2002-11-25
# 4       2003-07-10
#            ...
# 62349   1997-03-06
# 62350   1996-05-28
# 62351   1996-05-28
# 62352   1995-03-29
# 62353   1993-01-10
# Name: birthday, Length: 62354, dtype: datetime64[ns]>

# %%
#removing rows with later date than current date
df_merged = df_merged[(df_merged['avail_date'] <= today) & (df_merged['birthday'] <= today)]

# %%
#removing rows when avail_date happens before birthday
df_merged = df_merged[(df_merged['avail_date'] > df_merged['birthday'])]

# %%
#confirming
print(df_merged['birthday'].max())
print(df_merged['avail_date'].max())

print(df_merged[(df_merged['avail_date'] <= df_merged['birthday'])])
# Out:
# 2010-12-30 00:00:00
# 2023-11-23 00:00:00
# Empty DataFrame
# Columns: [txn_id, avail_date, last_name, first_name, birthday, branch_name, service, price]
# Index: []

# %%
df_merged.sample(20)
# Out:
#           txn_id avail_date   last_name first_name   birthday    branch_name  \
# 54630  TXN-45593 2017-03-07      HICKLE    QUENTIN 2009-10-17        MayMall
# 21852  TXN-65431 2008-03-11   LUEILWITZ      LELIA 1998-03-13      SmallMall
# 5155   TXN-34399 2019-07-14      PARKER    JEREMIE 1991-03-02        MayMall
# 29039  TXN-50722 2022-08-30       YUNDT   GRETCHEN 2007-06-02       Starmall
# 25174  TXN-14299 2009-01-19     WUCKERT    TERENCE 1991-12-12  RobinsonsMall
# 25902  TXN-22920 2009-12-09     GLEASON     JERAMY 2004-02-13       Starmall
# 1988   TXN-23014 2010-01-08     DIBBERT     GLENDA 1993-04-30  RobinsonsMall
# 25827  TXN-00282 2017-03-19      HANSEN      ANIKA 2005-08-28        MayMall
# 11665  TXN-64803 2017-03-10   MARQUARDT        KAY 1992-08-12  RobinsonsMall
# 4889   TXN-06643 2022-04-20     HILPERT      JACEY 2009-02-01       Megamall
# 56645  TXN-53274 2010-09-30      HELLER       ARIC 1998-02-13       Megamall
# 18314  TXN-62407 2009-08-04  MORISSETTE   CHRISTOP 1999-01-28      SmallMall
# 1373   TXN-36523 2013-03-23        BODE      PAULA 2010-09-30      SmallMall
# 20472  TXN-26547 2020-07-21        BINS    VALERIE 2008-11-12      FrankMall
# 10562  TXN-04414 2008-08-20    JACOBSON   CLOTILDE 1990-09-01       Megamall
# 7981   TXN-52646 2011-05-06      HAMMES   BROOKLYN 2004-06-13  RobinsonsMall
# 37552  TXN-55315 2019-05-18     QUITZON     ALANIS 1994-01-17     MallOfAsia
# 49861  TXN-09941 2016-04-08      WALKER       LOMA 2003-06-06     MallOfAsia
# 60758  TXN-34140 2007-08-26    LUETTGEN     KAYDEN 2002-01-18      FrankMall
# 18043  TXN-32777 2019-03-12       TROMP   RODERICK 1996-04-22      SmallMall
#
#          service      price
# 54630  HairColor  88.093930
# 21852   Pedicure   0.000000
# 5155   NailColor  22.716300
# 29039  NailColor  30.123790
# 25174   Manicure  55.232400
# 25902    Haircut  66.123457
# 1988     FootSpa  75.620543
# 25827  HairColor  88.093930
# 11665    Haircut   0.000000
# 4889   HairColor  69.964710
# 56645  HairColor  88.093930
# 18314  NailColor   0.000000
# 1373     FootSpa  80.037329
# 20472    Haircut   0.000000
# 10562  HairColor  69.964710
# 7981   NailColor  23.306676
# 37552  HairColor  88.093930
# 49861  HairColor  88.093930
# 60758    Haircut  66.123457
# 18043  HairColor   0.000000

# %%
df_merged.shape
# Out:
# (43136, 8)

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.9-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Using cached psycopg2_binary-2.9.9-cp312-cp312-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2-binary
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\juanc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\psycopg2\\_psycopg.cp312-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import psycopg2

# %%
conn = psycopg2.connect("dbname=transaction user=postgres password=postgres")

# %%
cur = conn.cursor()

# %%
cur.execute("create table if not exists transaction_table (txn_id varchar(45) not null primary key,avail_data date, last_name varchar(20),birthday date,branch_name varchar(30), service varchar(30), price double precision)")
